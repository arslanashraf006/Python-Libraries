# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv")
df
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
# skiprows can skip the data of row
df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", skiprows = 1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
# also use header to define the exact row header and skip the other data

df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", header = 1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
# if you don't have header you can say header is None
df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", header = None)
df
# Out:
#             0              1        2      3              4
# 0  stock data            NaN      NaN    NaN            NaN
# 1     tickers            eps  revenue  price         people
# 2       GOOGL          27.82       87    845     larry page
# 3         WMT           4.61      484     65           n.a.
# 4        MSFT             -1       85     64     bill gates
# 5        RIL   not available       50   1023  mukesh ambani
# 6        TATA            5.6       -1   n.a.     ratan tata

# %%
# if you don't have header you can say header is None and also gives the headers name
df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", header = None, names=["ticker", "eps", "revenue", "price", "people"])
df
# Out:
#        ticker            eps  revenue  price         people
# 0  stock data            NaN      NaN    NaN            NaN
# 1     tickers            eps  revenue  price         people
# 2       GOOGL          27.82       87    845     larry page
# 3         WMT           4.61      484     65           n.a.
# 4        MSFT             -1       85     64     bill gates
# 5        RIL   not available       50   1023  mukesh ambani
# 6        TATA            5.6       -1   n.a.     ratan tata

# %%
# number of rows you want to read with your header

df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", nrows = 3)
df
# Out:
#   stock data Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0    tickers        eps    revenue      price      people
# 1      GOOGL      27.82         87        845  larry page
# 2        WMT       4.61        484         65        n.a.

# %%
# if you don't have number values
df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data.csv", na_values = ["not available", "n.a."])
df
# Out:
#   stock data Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers        eps    revenue      price         people
# 1      GOOGL      27.82         87        845     larry page
# 2        WMT       4.61        484         65            NaN
# 3       MSFT         -1         85         64     bill gates
# 4       RIL         NaN         50       1023  mukesh ambani
# 5       TATA        5.6         -1        NaN     ratan tata

# %%
# convert specific single value according to single column data value, you can use dictionary
# used to cleaning data,

df = pd.read_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\stock_data1.csv", na_values = {
    'eps': ['not avaialabe', "n.a."],
    'revenue': ['not avaialabe', "n.a.", -1],
    'people': ['not avaialabe', "n.a."]
})
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82     87.0   845     larry page
# 1     WMT           4.61    484.0    65            NaN
# 2    MSFT             -1     85.0    64     bill gates
# 3    RIL   not available     50.0  1023  mukesh ambani
# 4    TATA            5.6      NaN  n.a.     ratan tata

# %%
# write back to csv file

# df.to_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\new.csv")

# remove the index
df.to_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\new.csv", index = False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
#want to write only specific columns

df.to_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\new.csv", columns = ['tickers', 'eps'])

# %%
#dont want to add headers

df.to_csv("C:\\Users\\REGEN\\Documents\\python libraries\\pandas\\new.csv", header = False)
