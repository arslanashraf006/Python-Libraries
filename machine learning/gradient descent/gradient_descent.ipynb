# %% [markdown]
# What is prdiction function and how it is calculated.
#
# A prediction function is a mathematical or statistical tool used to estimate future outcomes based on past data.

# %% [markdown]
# ![Screenshot 2025-10-26 161407.png](attachment:6ffd5647-aeea-4ffc-a61b-ac113560711f.png)

# %% [markdown]
# Mean Squared Error (MSE) is a statistical metric that measures the average of the squares of the differences between predicted and actual values in a model.
#
#
# ![Screenshot 2025-10-26 162030.png](attachment:edbbc09a-3aa7-4b43-9c2b-b48ace1f0463.png)
#
# ![Screenshot 2025-10-26 162141.png](attachment:cdb67211-8a9e-46ae-a596-17518e243007.png)

# %% [markdown]
# Gradient descent is an algorithm that finds best fit line for giving training data set.
#
# ![Screenshot 2025-10-26 162750.png](attachment:e95a59c1-0e0c-4b14-b24f-aa3975ff9f64.png)
#
# ![Screenshot 2025-10-26 163021.png](attachment:a14e78c4-92d5-4695-8494-fd1ae4695cc8.png)
#
# ![Screenshot 2025-10-26 170026.png](attachment:06aaaf1b-6428-4540-8f9c-4384308f4b67.png)

# %% [markdown]
# What is derivative and partial derivative read from net.

# %% [markdown]
# Partial derivate of b and m
#
# ![Screenshot 2025-10-26 173513.png](attachment:892cfcf7-b98a-4cf7-9f4f-ca00cf36d155.png)

# %% [markdown]
# ![Screenshot 2025-10-26 174033.png](attachment:2563d6ac-f0cf-45de-a1a3-c41be517fe88.png)
#
# ![Screenshot 2025-10-26 173953.png](attachment:55f48212-1f35-4c75-b243-54929c469fdf.png)
