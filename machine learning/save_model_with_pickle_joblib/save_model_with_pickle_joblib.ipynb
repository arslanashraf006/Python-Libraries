# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("C://Users//REGEN//Documents//python libraries//machine learning//save_model_with_pickle_joblib//homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
# value of coffecient (means slope) from y = mx + b
reg.coef_
# Out:
# array([135.78767123])

# %%
# value of intercept

reg.intercept_
# Out:
# 180616.43835616432

# %%
# predict the price of area 5000 sqft

reg.predict([[5000]])
# Out:
# C:\Users\REGEN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
# Save Model To a File Using Python Pickle

import pickle

# %%
# Load Saved Model
# wb for writing also binary mode is important
with open('model_pickle', 'wb') as f:
    pickle.dump(reg,f)

# %%
 # rb for reading also binary mode is important
with open('model_pickle', 'rb') as f:
     model = pickle.load(f)

# %%
model.predict([[5000]])
# Out:
# C:\Users\REGEN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
#Save Trained Model Using joblib
# if your model consist of large numpy array then using joblib might be more efficient

import joblib

# %%
# save the model
joblib.dump(reg, 'C://Users//REGEN//Documents//python libraries//machine learning//save_model_with_pickle_joblib//model_joblib')
# Out:
# ['C://Users//REGEN//Documents//python libraries//machine learning//save_model_with_pickle_joblib//model_joblib']

# %%
# load the model

mj = joblib.load("C://Users//REGEN//Documents//python libraries//machine learning//save_model_with_pickle_joblib//model_joblib")

# %%
mj.predict([[5000]])
# Out:
# C:\Users\REGEN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
